# %% [markdown]
# <a href="https://colab.research.google.com/github/soniasafaii/tennis_project/blob/main/TennisProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import path
#each person should write their own file-path
data_path = path(r"")
